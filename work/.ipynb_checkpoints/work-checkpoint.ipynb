# %%
link = "https://www.thegreyhoundrecorder.com.au/results/hatrick/67834"

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
raw_html = simple_get(link)
len(raw_html)
# Out:
# 342192

# %%
html = BeautifulSoup(raw_html, 'html.parser')

# %%
import sys

orig_stdout = sys.stdout
f = open('out1.html', 'w')
sys.stdout = f

print(html)

sys.stdout = orig_stdout
f.close()

# %%
mydivs = html.findAll("div", {"class": "runnerSubDetails"})

# %%
print(mydivs)
# Out:
# [<div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>17.96</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>311</div>
# <div><p>Wgt</p>35.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>1.70                          </div>
# <div><p>Time</p>18.07</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>222</div>
# <div><p>Wgt</p>32.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>5.60                          </div>
# <div><p>Time</p>18.31</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>553</div>
# <div><p>Wgt</p>30.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>6.40                          </div>
# <div><p>Time</p>18.36</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>434</div>
# <div><p>Wgt</p>31.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.60                          </div>
# <div><p>Time</p>18.50</div>
# <div><p>Split</p>7.12</div>
# <div><p>In Run</p>145</div>
# <div><p>Wgt</p>27.2kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>18.05</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>311</div>
# <div><p>Wgt</p>28.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>2.80                          </div>
# <div><p>Time</p>18.23</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>552</div>
# <div><p>Wgt</p>32.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.70                          </div>
# <div><p>Time</p>18.35</div>
# <div><p>Split</p>7.09</div>
# <div><p>In Run</p>123</div>
# <div><p>Wgt</p>25.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>5.10                          </div>
# <div><p>Time</p>18.37</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>664</div>
# <div><p>Wgt</p>33.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>5.20                          </div>
# <div><p>Time</p>18.38</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>435</div>
# <div><p>Wgt</p>32.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>6.20                          </div>
# <div><p>Time</p>18.44</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>776</div>
# <div><p>Wgt</p>32.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>7.70                          </div>
# <div><p>Time</p>18.54</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>887</div>
# <div><p>Wgt</p>30.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.00                          </div>
# <div><p>Time</p>18.55</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>248</div>
# <div><p>Wgt</p>35.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>45.35</div>
# <div><p>Split</p>17.93</div>
# <div><p>In Run</p>11222</div>
# <div><p>Wgt</p>28.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.80                          </div>
# <div><p>Time</p>45.40</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>32111</div>
# <div><p>Wgt</p>32.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.80                          </div>
# <div><p>Time</p>45.59</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>43543</div>
# <div><p>Wgt</p>30.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.90                          </div>
# <div><p>Time</p>45.66</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>77876</div>
# <div><p>Wgt</p>26.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>7.70                          </div>
# <div><p>Time</p>45.84</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>88787</div>
# <div><p>Wgt</p>25.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>9.90                          </div>
# <div><p>Time</p>45.97</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>26668</div>
# <div><p>Wgt</p>26.9kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>12.10                          </div>
# <div><p>Time</p>46.11</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>55455</div>
# <div><p>Wgt</p>29.2kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>25.70                          </div>
# <div><p>Time</p>46.97</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>64334</div>
# <div><p>Wgt</p>28.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>18.06</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>511</div>
# <div><p>Wgt</p>26.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.50                          </div>
# <div><p>Time</p>18.28</div>
# <div><p>Split</p>7.12</div>
# <div><p>In Run</p>122</div>
# <div><p>Wgt</p>31.2kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>5.00                          </div>
# <div><p>Time</p>18.38</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>333</div>
# <div><p>Wgt</p>25.3kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>15.90                          </div>
# <div><p>Time</p>19.06</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>644</div>
# <div><p>Wgt</p>25.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>18.40                          </div>
# <div><p>Time</p>19.22</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>756</div>
# <div><p>Wgt</p>31.3kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>0.00</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>2f5</div>
# <div><p>Wgt</p>25.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>0.00</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>4fp</div>
# <div><p>Wgt</p>27.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>17.72</div>
# <div><p>Split</p>6.84</div>
# <div><p>In Run</p>111</div>
# <div><p>Wgt</p>33.2kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.30                          </div>
# <div><p>Time</p>17.93</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>432</div>
# <div><p>Wgt</p>27.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.40                          </div>
# <div><p>Time</p>18.00</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>653</div>
# <div><p>Wgt</p>33.9kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.90                          </div>
# <div><p>Time</p>18.03</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>224</div>
# <div><p>Wgt</p>28.3kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>6.40                          </div>
# <div><p>Time</p>18.12</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>545</div>
# <div><p>Wgt</p>26.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>6.80                          </div>
# <div><p>Time</p>18.15</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>766</div>
# <div><p>Wgt</p>27.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>7.70                          </div>
# <div><p>Time</p>18.21</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>377</div>
# <div><p>Wgt</p>33.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.80                          </div>
# <div><p>Time</p>18.27</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>888</div>
# <div><p>Wgt</p>25.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>30.55</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>41111</div>
# <div><p>Wgt</p>26.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.40                          </div>
# <div><p>Time</p>30.76</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>32222</div>
# <div><p>Wgt</p>35.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.00                          </div>
# <div><p>Time</p>30.80</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>74433</div>
# <div><p>Wgt</p>28.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.50                          </div>
# <div><p>Time</p>30.83</div>
# <div><p>Split</p>5.14</div>
# <div><p>In Run</p>13344</div>
# <div><p>Wgt</p>33.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.60                          </div>
# <div><p>Time</p>31.09</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>35675</div>
# <div><p>Wgt</p>25.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>13.30                          </div>
# <div><p>Time</p>31.39</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>57556</div>
# <div><p>Wgt</p>29.9kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>13.40                          </div>
# <div><p>Time</p>31.39</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>76767</div>
# <div><p>Wgt</p>30.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>14.30                          </div>
# <div><p>Time</p>31.45</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>68888</div>
# <div><p>Wgt</p>27.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>17.86</div>
# <div><p>Split</p>7.09</div>
# <div><p>In Run</p>111</div>
# <div><p>Wgt</p>32.0kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.60                          </div>
# <div><p>Time</p>18.09</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>522</div>
# <div><p>Wgt</p>25.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.90                          </div>
# <div><p>Time</p>18.17</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>333</div>
# <div><p>Wgt</p>29.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.40                          </div>
# <div><p>Time</p>18.39</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>454</div>
# <div><p>Wgt</p>29.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>11.00                          </div>
# <div><p>Time</p>18.55</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>245</div>
# <div><p>Wgt</p>26.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>11.30                          </div>
# <div><p>Time</p>18.57</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>766</div>
# <div><p>Wgt</p>24.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>12.30                          </div>
# <div><p>Time</p>18.63</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>877</div>
# <div><p>Wgt</p>25.9kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>16.40                          </div>
# <div><p>Time</p>18.89</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>688</div>
# <div><p>Wgt</p>30.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>17.70</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>211</div>
# <div><p>Wgt</p>31.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.30                          </div>
# <div><p>Time</p>17.91</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>322</div>
# <div><p>Wgt</p>28.2kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.70                          </div>
# <div><p>Time</p>17.93</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>533</div>
# <div><p>Wgt</p>33.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.40                          </div>
# <div><p>Time</p>18.23</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>474</div>
# <div><p>Wgt</p>33.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.80                          </div>
# <div><p>Time</p>18.25</div>
# <div><p>Split</p>7.01</div>
# <div><p>In Run</p>145</div>
# <div><p>Wgt</p>30.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>10.90                          </div>
# <div><p>Time</p>18.39</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>766</div>
# <div><p>Wgt</p>25.3kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>11.00                          </div>
# <div><p>Time</p>18.39</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>657</div>
# <div><p>Wgt</p>28.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>11.60                          </div>
# <div><p>Time</p>18.43</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>888</div>
# <div><p>Wgt</p>30.3kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>30.66</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>52111</div>
# <div><p>Wgt</p>31.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>1.20                          </div>
# <div><p>Time</p>30.74</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>44322</div>
# <div><p>Wgt</p>26.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>1.60                          </div>
# <div><p>Time</p>30.76</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>66553</div>
# <div><p>Wgt</p>32.0kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>2.80                          </div>
# <div><p>Time</p>30.84</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>21234</div>
# <div><p>Wgt</p>29.8kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>5.20                          </div>
# <div><p>Time</p>30.99</div>
# <div><p>Split</p>5.16</div>
# <div><p>In Run</p>13445</div>
# <div><p>Wgt</p>30.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.00                          </div>
# <div><p>Time</p>31.16</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>35666</div>
# <div><p>Wgt</p>30.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>17.96</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>511</div>
# <div><p>Wgt</p>32.9kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>3.20                          </div>
# <div><p>Time</p>18.16</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>632</div>
# <div><p>Wgt</p>27.3kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.90                          </div>
# <div><p>Time</p>18.27</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>243</div>
# <div><p>Wgt</p>35.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>5.20                          </div>
# <div><p>Time</p>18.29</div>
# <div><p>Split</p>7.10</div>
# <div><p>In Run</p>124</div>
# <div><p>Wgt</p>33.0kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>6.50                          </div>
# <div><p>Time</p>18.37</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>755</div>
# <div><p>Wgt</p>34.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.00                          </div>
# <div><p>Time</p>18.46</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>866</div>
# <div><p>Wgt</p>31.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>10.60                          </div>
# <div><p>Time</p>18.63</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>487</div>
# <div><p>Wgt</p>29.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>11.50                          </div>
# <div><p>Time</p>18.68</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>378</div>
# <div><p>Wgt</p>33.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>18.15</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>411</div>
# <div><p>Wgt</p>28.9kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>1.00                          </div>
# <div><p>Time</p>18.21</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>222</div>
# <div><p>Wgt</p>28.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>2.70                          </div>
# <div><p>Time</p>18.32</div>
# <div><p>Split</p>7.22</div>
# <div><p>In Run</p>133</div>
# <div><p>Wgt</p>27.6kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.70                          </div>
# <div><p>Time</p>18.45</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>744</div>
# <div><p>Wgt</p>30.4kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>4.80                          </div>
# <div><p>Time</p>18.45</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>555</div>
# <div><p>Wgt</p>36.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>7.50                          </div>
# <div><p>Time</p>18.62</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>666</div>
# <div><p>Wgt</p>26.3kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>8.70                          </div>
# <div><p>Time</p>18.70</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>387</div>
# <div><p>Wgt</p>25.0kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>9.50                          </div>
# <div><p>Time</p>18.75</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>878</div>
# <div><p>Wgt</p>27.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.00                          </div>
# <div><p>Time</p>18.30</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>341</div>
# <div><p>Wgt</p>27.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.40                          </div>
# <div><p>Time</p>18.33</div>
# <div><p>Split</p>7.19</div>
# <div><p>In Run</p>112</div>
# <div><p>Wgt</p>27.7kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>0.80                          </div>
# <div><p>Time</p>18.35</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>423</div>
# <div><p>Wgt</p>28.5kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>1.40                          </div>
# <div><p>Time</p>18.39</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>554</div>
# <div><p>Wgt</p>25.9kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>1.70                          </div>
# <div><p>Time</p>18.41</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>665</div>
# <div><p>Wgt</p>32.2kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>1.90                          </div>
# <div><p>Time</p>18.42</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>236</div>
# <div><p>Wgt</p>25.1kg</div>
# </div>, <div class="runnerSubDetails">
# <div><p>Mgn</p>5.10                          </div>
# <div><p>Time</p>18.62</div>
# <div><p>Split</p>0.00</div>
# <div><p>In Run</p>777</div>
# <div><p>Wgt</p>27.4kg</div>
# </div>]
